# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
data_csv = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(data_csv)

# %%
# Group dataframe by "SN" and count number of unique names
player_unique_df = purchase_data_df.drop_duplicates(subset="SN")
player_count = len(player_unique_df)

# Display total player count as dataframe and format column name
player_count_df = pd.DataFrame([player_count])
player_count_df.columns = ["Total Players"]

player_count_df
# Out:
#    Total Players
# 0            576

# %%
player_unique_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 774          774     Jiskjask80   11    Male       92
# 775          775     Aethedru70   21  Female       60
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 773              Pursuit, Cudgel of Necromancy   1.02
# 774                               Final Critic   4.19
# 775                                       Wolf   3.54
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
#
# [576 rows x 7 columns]

# %%
# Calculations for Purchasing Analysis = # Unique Items, Average Purchase Price, # of Purchases, and Total Revenue
unique_items = len(purchase_data_df["Item ID"].unique())
average_price = purchase_data_df["Price"].mean()
total_purchase_count = len(purchase_data_df["Purchase ID"].unique())
total_revenue = purchase_data_df["Price"].sum()

unique_items, average_price, total_purchase_count,total_revenue

#Define variable for and print summary table
summary = {"Number of Unique Items":unique_items,"Average Purchase Price":average_price,"Number of Purchases":total_purchase_count,"Total Revenue":total_revenue}
Purchasing_analysis_df = pd.DataFrame([summary])

Purchasing_analysis_df
# Out:
#    Number of Unique Items  Average Purchase Price  Number of Purchases  \
# 0                     179                3.050987                  780
#
#    Total Revenue
# 0        2379.77

# %%
# Calculate Count of Players by Gender. Rename column to Total Count

SN_gender = purchase_data_df.groupby("Gender").count()
# SN_gender = SN_gender[["Gender","SN"]]
gender_df = pd.DataFrame(SN_gender)
gender_data_df = gender_df.rename(columns={"SN":"Total Count"})
# gender_data_df = gender_data_df["Total Count"]

gender_data_df

# SN_gender= purchase_data_df.groupby("Gender").count()
# SN_gender
# Out:
#                        Purchase ID  Total Count  Age  Item ID  Item Name  \
# Gender
# Female                         113          113  113      113        113
# Male                           652          652  652      652        652
# Other / Non-Disclosed           15           15   15       15         15
#
#                        Price
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15

# %%
# Calculation for population size by percentage, create DataFrame
gender_percentage = (gender_data_df["Total Count"] / player_count)*100
gender_percentage = gender_percentage.apply("{:.2f}%".format)

# Rename results column to Percentage
gender_percentage_df = pd.DataFrame(gender_percentage)
gender_percentage_df = gender_percentage_df.rename(columns={"Total Count":"Percentage of Players"})

gender_percentage_df
# Out:
#                       Percentage of Players
# Gender
# Female                               19.62%
# Male                                113.19%
# Other / Non-Disclosed                 2.60%

# %%
# Merge 2 dataframes to show count and percentage. Source: https://www.dataindependent.com/pandas/pandas-merge/

gender_demographics_df = pd.merge(gender_data_df["Total Count"],gender_percentage_df["Percentage of Players"],on="Gender")
gender_demographics_df
# Out:
#                        Total Count Percentage of Players
# Gender
# Female                         113                19.62%
# Male                           652               113.19%
# Other / Non-Disclosed           15                 2.60%

# %%
gender_data_df
# Out:
#                        Purchase ID  Total Count  Age  Item ID  Item Name  \
# Gender
# Female                         113          113  113      113        113
# Male                           652          652  652      652        652
# Other / Non-Disclosed           15           15   15       15         15
#
#                        Price
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15

# %%
# Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
gender_purch_count = gender_data_df["Total Count"]
gender_average = gender_data_df["Price"].mean()
total_purchase_count = len(purchase_data_df["Purchase ID"].unique())
total_revenue = purchase_data_df["Price"].sum()

unique_items, average_price, total_purchase_count,total_revenue

#Define variable for and print summary table
summary = {"Number of Unique Items":unique_items,"Average Purchase Price":average_price,"Number of Purchases":total_purchase_count,"Total Revenue":total_revenue}
Purchasing_analysis_df = pd.DataFrame([summary])

Purchasing_analysis_df



# Create a summary data frame to hold the results


# Optional: give the displayed data cleaner formatting


# Display the summary data frame
